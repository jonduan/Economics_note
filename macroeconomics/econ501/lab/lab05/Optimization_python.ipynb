# %% [markdown]
# # Chapter 6: Optimization

# %% [markdown]
# Robert Johansson
#
# Source code listings for [Numerical Python - A Practical Techniques Approach for Industry](http://www.apress.com/9781484205549) (ISBN 978-1-484205-54-9).
#
# The source code listings can be downloaded from http://www.apress.com/9781484205549

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import sympy

# %%
sympy.init_printing()

# %%
from scipy import optimize

# %%
#import cvxopt

# %%
from __future__ import division

# %% [markdown]
# ## Univariate

# %%
r, h = sympy.symbols("r, h")

# %%
Area = 2 * sympy.pi * r**2 + 2 * sympy.pi * r * h

# %%
Volume = sympy.pi * r**2 * h

# %%
h_r = sympy.solve(Volume - 1)[0]

# %%
Area_r = Area.subs(h_r)

# %%
rsol = sympy.solve(Area_r.diff(r))[0]

# %%
rsol
# Out:
#    2/3
#   2
# ───────
#   3 ___
# 2⋅╲╱ π

# %%
_.evalf()
# Out:
# 0.541926070139289

# %%
# verify that the second derivative is positive, so that rsol is a minimum
Area_r.diff(r, 2).subs(r, rsol)
# Out:
# 12⋅π

# %%
Area_r.subs(r, rsol)
# Out:
#   3 ___ 3 ___
# 3⋅╲╱ 2 ⋅╲╱ π

# %%
_.evalf()
# Out:
# 5.53581044593209

# %%
def f(r):
    return 2 * np.pi * r**2 + 2 / r

# %%
r_min = optimize.brent(f, brack=(0.1, 4))

# %%
r_min
# Out:
# 0.541926077256

# %%
f(r_min)
# Out:
# 5.53581044593

# %%
optimize.minimize_scalar(f, bracket=(0.1, 5))
# Out:
#      fun: 5.5358104459320856
#     nfev: 14
#      nit: 13
#  success: True
#        x: 0.54192606489766715

# %%
r = np.linspace(0, 2, 100)

# %%
fig, ax = plt.subplots(figsize=(8, 4))

ax.plot(r, f(r), lw=2, color='b')
ax.plot(r_min, f(r_min), 'r*', markersize=15)
ax.set_title(r"$f(r) = 2\pi r^2+2/r$", fontsize=18)
ax.set_xlabel(r"$r$", fontsize=18)
ax.set_xticks([0, 0.5, 1, 1.5, 2])
ax.set_ylim(0, 30)

fig.tight_layout()
#fig.savefig('ch6-univariate-optimization-example.pdf')
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: RuntimeWarning: divide by zero encountered in true_divide
#   from ipykernel import kernelapp as app

# %% [markdown]
# ## Two-dimensional

# %%
x1, x2 = sympy.symbols("x_1, x_2")

# %%
f_sym = (x1-1)**4 + 5 * (x2-1)**2 - 2*x1*x2

# %%
fprime_sym = [f_sym.diff(x_) for x_ in (x1, x2)]

# %%
# Gradient
sympy.Matrix(fprime_sym)
# Out:
# ⎡                  3⎤
# ⎢-2⋅x₂ + 4⋅(x₁ - 1) ⎥
# ⎢                   ⎥
# ⎣-2⋅x₁ + 10⋅x₂ - 10 ⎦

# %%
fhess_sym = [[f_sym.diff(x1_, x2_) for x1_ in (x1, x2)] for x2_ in (x1, x2)]

# Hessian
sympy.Matrix(fhess_sym)
# Out:
# ⎡           2    ⎤
# ⎢12⋅(x₁ - 1)   -2⎥
# ⎢                ⎥
# ⎣     -2       10⎦

# %%
f_lmbda = sympy.lambdify((x1, x2), f_sym, 'numpy')

# %%
fprime_lmbda = sympy.lambdify((x1, x2), fprime_sym, 'numpy')

# %%
fhess_lmbda = sympy.lambdify((x1, x2), fhess_sym, 'numpy')

# %%
def func_XY_X_Y(f):
    """
    Wrapper for f(X) -> f(X[0], X[1])
    """
    return lambda X: np.array(f(X[0], X[1]))

# %%
f = func_XY_X_Y(f_lmbda)

# %%
fprime = func_XY_X_Y(fprime_lmbda)

# %%
fhess = func_XY_X_Y(fhess_lmbda)

# %%
X_opt = optimize.fmin_ncg(f, (0, 0), fprime=fprime, fhess=fhess)
# Out:
# Optimization terminated successfully.
#          Current function value: -3.867223
#          Iterations: 8
#          Function evaluations: 10
#          Gradient evaluations: 17
#          Hessian evaluations: 8

# %%
X_opt
# Out:
# array([ 1.88292613,  1.37658523])

# %%
fig, ax = plt.subplots(figsize=(6, 4))
x_ = y_ = np.linspace(-1, 4, 100)
X, Y = np.meshgrid(x_, y_)
c = ax.contour(X, Y, f_lmbda(X, Y), 50)
ax.plot(X_opt[0], X_opt[1], 'r*', markersize=15)
ax.set_xlabel(r"$x_1$", fontsize=18)
ax.set_ylabel(r"$x_2$", fontsize=18)
plt.colorbar(c, ax=ax)
fig.tight_layout()
#fig.savefig('ch6-examaple-two-dim.pdf');

# %%
from sympy import *
# %matplotlib inline

plotting.plot3d((f_sym),(x1,-4,4),(x2,-4,4))

# %% [markdown]
# ## Brute force search for initial point

# %%
def f(X):
    x, y = X
    return (4 * np.sin(np.pi * x) + 6 * np.sin(np.pi * y)) + (x - 1)**2 + (y - 1)**2

# %%
x_start = optimize.brute(f, (slice(-3, 5, 0.5), slice(-3, 5, 0.5)), finish=None)

# %%
x_start
# Out:
# array([ 1.5,  1.5])

# %%
f(x_start)
# Out:
# -9.5

# %%
x_opt = optimize.fmin_bfgs(f, x_start)
# Out:
# Optimization terminated successfully.
#          Current function value: -9.520229
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7

# %%
x_opt
# Out:
# array([ 1.47586906,  1.48365787])

# %%
f(x_opt)
# Out:
# -9.52022927306

# %%
def func_X_Y_to_XY(f, X, Y):
    s = np.shape(X)
    return f(np.vstack([X.ravel(), Y.ravel()])).reshape(*s)

# %%
fig, ax = plt.subplots(figsize=(6, 4))
x_ = y_ = np.linspace(-3, 5, 100)
X, Y = np.meshgrid(x_, y_)
c = ax.contour(X, Y, func_X_Y_to_XY(f, X, Y), 25)
ax.plot(x_opt[0], x_opt[1], 'r*', markersize=15)
ax.set_xlabel(r"$x_1$", fontsize=18)
ax.set_ylabel(r"$x_2$", fontsize=18)
plt.colorbar(c, ax=ax)
fig.tight_layout()
#fig.savefig('ch6-example-2d-many-minima.pdf');

# %%
import numpy as np
var('x y')
plotting.plot3d(((4 * sin(pi * x) + 6 * sin(pi * y)) + 
                 (x - 1)**2 + (y - 1)**2),(x,-3,5),(y,-3,5))

# %% [markdown]
# ## Nonlinear least square

# %%
def f(x, beta0, beta1, beta2):
    return beta0 + beta1 * np.exp(-beta2 * x**2)

# %%
beta = (0.25, 0.75, 0.5)

# %%
xdata = np.linspace(0, 5, 50)

# %%
y = f(xdata, *beta)

# %%
ydata = y + 0.05 * np.random.randn(len(xdata))

# %%
def g(beta):
    return ydata - f(xdata, *beta)

# %%
beta_start = (1, 1, 1)

# %%
beta_opt, beta_cov = optimize.leastsq(g, beta_start)

# %%
beta_opt
# Out:
# array([ 0.25215545,  0.70779394,  0.43716078])

# %%
fig, ax = plt.subplots()

ax.scatter(xdata, ydata)
ax.plot(xdata, y, 'r', lw=2)
ax.plot(xdata, f(xdata, *beta_opt), 'b', lw=2)
ax.set_xlim(0, 5)
ax.set_xlabel(r"$x$", fontsize=18)
ax.set_ylabel(r"$f(x, \beta)$", fontsize=18)

fig.tight_layout()
#fig.savefig('ch6-nonlinear-least-square.pdf')

# %%
beta_opt, beta_cov = optimize.curve_fit(f, xdata, ydata)

# %%
beta_opt
# Out:
# array([ 0.25215545,  0.70779394,  0.43716078])

# %% [markdown]
# ## Constrained optimization

# %% [markdown]
# ### Bounds

# %%
def f(X):
    x, y = X
    return (x-1)**2 + (y-1)**2

# %%
x_opt = optimize.minimize(f, (0, 0), method='BFGS').x

# %%
bnd_x1, bnd_x2 = (2, 3), (0, 2)

# %%
x_cons_opt = optimize.minimize(f, np.array([0, 0]), method='L-BFGS-B', bounds=[bnd_x1, bnd_x2]).x

# %%
fig, ax = plt.subplots(figsize=(6, 4))
x_ = y_ = np.linspace(-1, 3, 100)
X, Y = np.meshgrid(x_, y_)
c = ax.contour(X, Y, func_X_Y_to_XY(f, X, Y), 50)
ax.plot(x_opt[0], x_opt[1], 'b*', markersize=15)
ax.plot(x_cons_opt[0], x_cons_opt[1], 'r*', markersize=15)
bound_rect = plt.Rectangle((bnd_x1[0], bnd_x2[0]), 
                           bnd_x1[1] - bnd_x1[0], bnd_x2[1] - bnd_x2[0],
                           facecolor="grey")
ax.add_patch(bound_rect)
ax.set_xlabel(r"$x_1$", fontsize=18)
ax.set_ylabel(r"$x_2$", fontsize=18)
plt.colorbar(c, ax=ax)

fig.tight_layout()
#fig.savefig('ch6-example-constraint-bound.pdf');

# %%
var('x y')
plotting.plot3d(((x-1)**2 + (y-1)**2),(x,-3,5),(y,-3,5))

# %% [markdown]
# ## Lagrange multiplier

# %%
x = x1, x2, x3, lamb = sympy.symbols("x_1, x_2, x_3, lambda")

# %%
f = x1 * x2 * x3
f
# Out:
# x₁⋅x₂⋅x₃

# %%
g = 2 * (x1 * x2 + x2 * x3 + x3 * x1) - 1
g
# Out:
# 2⋅x₁⋅x₂ + 2⋅x₁⋅x₃ + 2⋅x₂⋅x₃ - 1

# %%
L = f + lamb * g
L
# Out:
# λ⋅(2⋅x₁⋅x₂ + 2⋅x₁⋅x₃ + 2⋅x₂⋅x₃ - 1) + x₁⋅x₂⋅x₃

# %%
grad_L = [sympy.diff(L, x_) for x_ in x]
grad_L
# Out:
# [λ⋅(2⋅x₂ + 2⋅x₃) + x₂⋅x₃, λ⋅(2⋅x₁ + 2⋅x₃) + x₁⋅x₃, λ⋅(2⋅x₁ + 2⋅x₂) + x₁⋅x₂, 2⋅
# x₁⋅x₂ + 2⋅x₁⋅x₃ + 2⋅x₂⋅x₃ - 1]

# %%
sols = sympy.solve(grad_L)
sols
# Out:
# ⎡⎧   -√6       √6      √6      √6⎫  ⎧   √6      -√6       -√6       -√6 ⎫⎤
# ⎢⎨λ: ────, x₁: ──, x₂: ──, x₃: ──⎬, ⎨λ: ──, x₁: ────, x₂: ────, x₃: ────⎬⎥
# ⎣⎩    24       6       6       6 ⎭  ⎩   24       6         6         6  ⎭⎦

# %%
g.subs(sols[0])
# Out:
# 0

# %%
f.subs(sols[0])
# Out:
# √6
# ──
# 36

# %%
g.subs(sols[1])
# Out:
# 0

# %%
f.subs(sols[1])
# Out:
# -√6
# ────
#  36

# %%
L.diff(x1,x1)
# Out:
# λ⋅(2⋅x₂ + 2⋅x₃) + x₂⋅x₃

# %%
Lhess_sym = [[L.diff(x1_, x2_) 
              for x1_ in (x1, x2,x3)] 
              for x2_ in (x1, x2,x3)]
             
# Hessian
Matrix(Lhess_sym)
# Out:
# ⎡   0      2⋅λ + x₃  2⋅λ + x₂⎤
# ⎢                            ⎥
# ⎢2⋅λ + x₃     0      2⋅λ + x₁⎥
# ⎢                            ⎥
# ⎣2⋅λ + x₂  2⋅λ + x₁     0    ⎦

# %%
Lbhess_sym = [[L.diff(x1_, x2_) 
              for x1_ in (lamb, x1, x2,x3)] 
              for x2_ in (lamb,x1, x2,x3)]

# Boarded Hessian
Matrix(Lbhess_sym)
# Out:
# ⎡     0       2⋅(x₂ + x₃)  2⋅(x₁ + x₃)  2⋅(x₁ + x₂)⎤
# ⎢                                                  ⎥
# ⎢2⋅(x₂ + x₃)       0        2⋅λ + x₃     2⋅λ + x₂  ⎥
# ⎢                                                  ⎥
# ⎢2⋅(x₁ + x₃)   2⋅λ + x₃         0        2⋅λ + x₁  ⎥
# ⎢                                                  ⎥
# ⎣2⋅(x₁ + x₂)   2⋅λ + x₂     2⋅λ + x₁         0     ⎦

# %%
# max
sols[0]
# Out:
# ⎧   -√6       √6      √6      √6⎫
# ⎨λ: ────, x₁: ──, x₂: ──, x₃: ──⎬
# ⎩    24       6       6       6 ⎭

# %%
Matrix(Lbhess_sym).subs(sols[0])
# Out:
# ⎡      2⋅√6  2⋅√6  2⋅√6⎤
# ⎢ 0    ────  ────  ────⎥
# ⎢       3     3     3  ⎥
# ⎢                      ⎥
# ⎢2⋅√6         √6    √6 ⎥
# ⎢────   0     ──    ── ⎥
# ⎢ 3           12    12 ⎥
# ⎢                      ⎥
# ⎢2⋅√6   √6          √6 ⎥
# ⎢────   ──    0     ── ⎥
# ⎢ 3     12          12 ⎥
# ⎢                      ⎥
# ⎢2⋅√6   √6    √6       ⎥
# ⎢────   ──    ──    0  ⎥
# ⎣ 3     12    12       ⎦

# %%
Matrix(Lbhess_sym).subs(sols[0]).det()
# Out:
# -1/3

# %%
Matrix(Lbhess_sym).subs(sols[0])[:3,:3]
# Out:
# ⎡      2⋅√6  2⋅√6⎤
# ⎢ 0    ────  ────⎥
# ⎢       3     3  ⎥
# ⎢                ⎥
# ⎢2⋅√6         √6 ⎥
# ⎢────   0     ── ⎥
# ⎢ 3           12 ⎥
# ⎢                ⎥
# ⎢2⋅√6   √6       ⎥
# ⎢────   ──    0  ⎥
# ⎣ 3     12       ⎦

# %%
Matrix(Lbhess_sym).subs(sols[0])[:3,:3].det()
# Out:
# 4⋅√6
# ────
#  9

# %%
Matrix(Lbhess_sym).subs(sols[0])[:2,:2]
# Out:
# ⎡      2⋅√6⎤
# ⎢ 0    ────⎥
# ⎢       3  ⎥
# ⎢          ⎥
# ⎢2⋅√6      ⎥
# ⎢────   0  ⎥
# ⎣ 3        ⎦

# %%
Matrix(Lbhess_sym).subs(sols[0])[:2,:2].det()
# Out:
# -8/3

# %%
# min
sols[1]
# Out:
# ⎧   √6      -√6       -√6       -√6 ⎫
# ⎨λ: ──, x₁: ────, x₂: ────, x₃: ────⎬
# ⎩   24       6         6         6  ⎭

# %%
Matrix(Lbhess_sym).subs(sols[1]).det()
# Out:
# -1/3

# %%
Matrix(Lbhess_sym).subs(sols[1])[:3,:3].det()
# Out:
# -4⋅√6
# ──────
#   9

# %%
Matrix(Lbhess_sym).subs(sols[1])[:2,:2].det()
# Out:
# -8/3

# %%
# add minus sigh
def f(X):
    return -X[0] * X[1] * X[2]

# %%
def g(X):
    return 2 * (X[0]*X[1] + X[1] * X[2] + X[2] * X[0]) - 1

# %%
constraints = [dict(type='eq', fun=g)]
#constraints

# %%
result = optimize.minimize(f, [0.5, 1, 1.5], method='SLSQP', constraints=constraints)

# %%
# max
result
# Out:
#      fun: -0.068041368622872966
#      jac: array([-0.16666925, -0.16666542, -0.16666526,  0.        ])
#  message: 'Optimization terminated successfully.'
#     nfev: 95
#      nit: 18
#     njev: 18
#   status: 0
#  success: True
#        x: array([ 0.40824188,  0.40825127,  0.40825165])

# %%
# max
result.x
# Out:
# array([ 0.40824187,  0.40825127,  0.40825165])

# %% [markdown]
# ## Inequality constraints

# %%
def f(X):
    return (X[0] - 1)**2 + (X[1] - 1)**2

def g(X):
    return X[1] - 1.75 - (X[0] - 0.75)**4

# %%
x_opt = optimize.minimize(f, (0, 0), method='BFGS').x

# %%
constraints = [dict(type='ineq', fun=g)]

# %%
x_cons_opt = optimize.minimize(f, (0, 0), method='SLSQP', constraints=constraints).x

# %%
x_cons_opt = optimize.minimize(f, (0, 0), method='COBYLA', constraints=constraints).x

# %%
fig, ax = plt.subplots(figsize=(6, 4))
x_ = y_ = np.linspace(-1, 3, 100)
X, Y = np.meshgrid(x_, y_)
c = ax.contour(X, Y, func_X_Y_to_XY(f, X, Y), 50)
ax.plot(x_opt[0], x_opt[1], 'b*', markersize=15)

ax.plot(x_, 1.75 + (x_-0.75)**4, 'k-', markersize=15)
ax.fill_between(x_, 1.75 + (x_-0.75)**4, 3, color="grey")
ax.plot(x_cons_opt[0], x_cons_opt[1], 'r*', markersize=15)

ax.set_ylim(-1, 3)
ax.set_xlabel(r"$x_0$", fontsize=18)
ax.set_ylabel(r"$x_1$", fontsize=18)
plt.colorbar(c, ax=ax)

fig.tight_layout()
#fig.savefig('ch6-example-constraint-inequality.pdf');

# %%
var('x y')
plotting.plot3d(((x - 1)**2 + (y - 1)**2),(x,-3,5),(y,-3,5))

# %% [markdown]
# ## Linear programming

# %%
c = np.array([-1.0, 2.0, -3.0])

A = np.array([[ 1.0, 1.0, 0.0],
              [-1.0, 3.0, 0.0],
              [ 0.0, -1.0, 1.0]])

b = np.array([1.0, 2.0, 3.0])

# %%
A_ = cvxopt.matrix(A)
b_ = cvxopt.matrix(b)
c_ = cvxopt.matrix(c)

# %%
sol = cvxopt.solvers.lp(c_, A_, b_)
# Out:
# Optimal solution found.

# %%
x = np.array(sol['x'])

# %%
x
# Out:
# array([[ 0.25],
#        [ 0.75],
#        [ 3.75]])

# %%
sol
# Out:
# {'dual infeasibility': 1.4835979218054372e-16,
#  'dual objective': -10.0,
#  'dual slack': 0.0,
#  'gap': 0.0,
#  'iterations': 0,
#  'primal infeasibility': 0.0,
#  'primal objective': -10.0,
#  'primal slack': -0.0,
#  'relative gap': 0.0,
#  'residual as dual infeasibility certificate': None,
#  'residual as primal infeasibility certificate': None,
#  's': <3x1 matrix, tc='d'>,
#  'status': 'optimal',
#  'x': <3x1 matrix, tc='d'>,
#  'y': <0x1 matrix, tc='d'>,
#  'z': <3x1 matrix, tc='d'>}

# %%
sol['primal objective']
# Out:
# -10.0

# %% [markdown]
# ## Versions

# %%
#%reload_ext version_information

# %%
# %version_information numpy, scipy,  sympy, matplotlib
# Out:
# Software versions
# Python 2.7.10 64bit [GCC 4.2.1 (Apple Inc. build 5577)]
# IPython 3.2.1
# OS Darwin 14.1.0 x86_64 i386 64bit
# numpy 1.9.2
# scipy 0.16.0
# cvxopt 1.1.7
# sympy 0.7.6
# matplotlib 1.4.3
# Mon Aug 03 23:07:03 2015 JST
