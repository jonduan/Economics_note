# %% [markdown]
# Lithium Ion: lithium ion storage technology
#
# NaS: sodium sulfur storage technology
#
# VRB: vanadium redox storage technology
#
# PHS: pumped hydro storage technology
#
# CAES: compressed air energy storage technology
#
#
#
#
#
# Lithium
# Ion No
# DTS 8MW
# Lithium
# Ion
# w/DTS 8MW
#
#
#
# NaS
# No
# DTS
#
# 8MW
# NaS
# w/DTS 8MW
#
#
#
# VRB
# No
# DTS 8MW
#
#
#
# VRB
# w/DTS 20MW
#
#
#
# Lithium
# Ion No
# DTS 20MW
#
#
#
# Lithium
# Ion
# w/DTS 20MW
#
#
#
# NaS
# No
# DTS 20MW
#
#
# NaS
# w/DTS 20MW
#
#
# VRB
# No
# DTS 20MW
#
#
# VRB
# w/DTS 150MW
#
#
# PHS No
# DTS 150MW
#
#
# PHS
# w/DTS 150MW
#
#
# CAES
# No DTS 150MW
#
#
# CAES
# w/DTS
#     150MW
