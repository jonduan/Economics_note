# %%
from sympy import *
# %matplotlib inline


init_printing(use_latex=True)

# %%
from __future__ import division
from sympy import *
x, y, z, t = symbols('x y z t')
k, m, n = symbols('k m n', integer=True)
f, g, h = symbols('f g h', cls=Function)
a, b, c, d ,p, q, qv, qr= symbols('a b c d p q  qv qr')

# %%
# p12 example
solve([15 - 0.5*(qv+qr) - (5 +qv), 5 + qv -(9 +qr) ], [qv, qr])
# Out:
# {qr: 2.0, qv: 6.0}

# %% [markdown]
# ## Question 1 (10 marks)
#
#
#
# Suppose that recycled and virgin aluminum are perfect substitutes. The demand for aluminum is given by P = 30 – 0.75Q, where Q = QV + QR. The supply of virgin and recycled aluminum is given by MCV = 1 + 0.5QV and MCR = 6 + 0.2QR, respectively. Assume that quantity is expressed in units; price and MC are in dollars per unit.
#
#
#
# a)	How many units of recycled and virgin materials should be used? Calculate the efficient recycling ratio. (5 marks)
# P10
#
# b)	Illustrate your answers to (a) on a clearly labeled diagram. (5 marks)

# %%
qv,qr = symbols("qv qr")

# %%
res = solve([30 - 0.75*(qv+qr) - (1+0.5*qr), 1+0.5*qv -(6+0.2*qr) ], [qv, qr])
res
# Out:
# {qr: 13.8709677419355, qv: 15.5483870967742}

# %%
res[qv]
# Out:
# 15.5483870967742

# %%
30 - 0.75*(res[qv]+res[qr])
# Out:
# 7.93548387096774

# %%
pq1 = plot(30 - 0.75*q, 1+0.5*q, 6+0.2*q ,(q,0, 45),  
           xlim = (0, 45)  , ylim =(-10,30), title = "MB,MCV, MCR",legend = True, show= False )

pq1[1].line_color = 'red'
pq1[2].line_color = 'green'
pq1.show()

# %%
p8 = plot_implicit(y - 7.9, y_var=(y, 0, 15) ,x_var=(q, 0, 45),line_color = "red", show = False)


pq1.extend(p8)
pq1.show()

# %%
#The efficient ra4o is 

res[qr]/(res[qv]+res[qr])
# Out:
# 0.471491228070175

# %% [markdown]
# Condition: MCV =MCR = MB

# %% [markdown]
# ## Question 2 (10 marks)
#
#
# California’s electricity market was one of the earliest to undergo deregulation, but the regulatory changes were implemented in stages. In the early 2000s, wholesale electricity prices (the price that electricity retailers paid generators for electricity) were not regulated. In other words, wholesale market prices were determined by supply and demand between generators and retailers. However, retail electricity prices (the price that retailers could charge consumers) were regulated, so a price ceiling was in effect in retail electricity market. Moreover, retailers were legally obligated to supply as much electricity as consumers demanded at the regulated price. This situation contributed to an electricity crisis —wholesale prices skyrocketed and retailers became unable to meet electricity demand. Consumers experienced rolling blackouts, and on some days, millions of households and businesses were completely without power.   Suppose that
#
# •	the wholesale electricity price was 15 cents per kilowatt hour (kWh)
#
# •	the retail electricity price was 10 cents per kWh
#
# •	aggregate consumer demand (retail market demand) was Q = 50,000 – 2,000P, where Q is in kWh and P is in cents/kWh.
#
#     a)	Provide a diagram illustrating the situation in the retail electricity market. Please clearly label all important elements (Note: Derive the inverse demand curve and draw the standard diagram with price along the vertical axis). (5 marks)
#
#     b)	Calculate consumer surplus in the retail electricity market (in dollars). Label the area corresponding to CS on the diagram in (a). (2 marks)
#
#     c)	Calculate producer surplus in the retail electricity market (in dollars). Label the area corresponding to PS on the diagram in (a). (2 marks)
#
#     d)	If the retail electricity price is not permitted to rise, what long-term consequences do you expect for the electricity market? (1 mark)

# %%
pq2 = plot(50/2 - 1/2000*q, (q,0, 50000),  xlim = (0, 50000)  , ylim =(0,30) ,title = "MB, CS, PS, DWL", legend = True)

# %%
pq21 = plot_implicit(y - 10, y_var =(y, 0, 30) , x_var=(q, 0, 50000),  line_color = "red", show = False)

pq22 = plot_implicit(y - 15, y_var =(y, 0, 30) , x_var=(q, 0, 50000),  line_color = "red", show = False)

pq2.extend(pq21)
pq2.extend(pq22)

pq2.show()

# %%
pq23 = plot_implicit(And(y > 10, y < 50/2 - 1/2000*q), y_var =(y, 0, 30) , x_var=(q, 0, 50000 ), line_color = "green",show = False)

pq2.extend(pq23)

pq2.show()

# %%
pq24 = plot_implicit( y < 50/2 - 1/2000*q, y_var =(y, 0, 30) , x_var=(q, 0, 50000 ), line_color = "red",show = False)
pq25 = plot_implicit(y > 15, y_var =(y, 0, 30) , x_var=(q, 0, 50000 ), line_color = "white",show = False)
pq26 = plot_implicit( y < 10, y_var =(y, 0, 30) , x_var=(q, 0, 50000 ), line_color = "white",show = False)
pq2.extend(pq24)
pq2.extend(pq25)
pq2.extend(pq26)

pq2.show()

# %% [markdown]
# ## Question 3
#
# Question 3 (20 marks)
# P 11 example
# Extracting oil from oil sands involves separating the oil from the sand and clay that it is mixed with. This process involves using large amounts of hot water and some chemicals. The wastes from this process are toxic and they are contained in tailings ponds. These tailings ponds impose a number of external costs—the toxic water may leach into the environment, polluting waterways and damaging habitats, waterfowl may land on the ponds and drown as a result of oiling, etc. Suppose that
# •	MB = 120 – 0.3Q  (there are no positive externalities)
# •	MPC = 24 + 0.3Q
# •	MEC = 0.2Q
# Q is in barrels. Marginal benefits and costs are in $/barrel.
#
# a)	In the absence of regulation, how much oil will a competitive industry extract? Calculate the CS, PS, EC, and NB. (6 marks)
# In the presence of a negative externality, the market outcome is inefficient.
# b)	Calculate the efficient extraction level and use a diagram to illustrate the DWL.
# (4	marks)
#
# p14
# c)	Explain how a Pigovian tax could be used to correct this market failure. Include a diagram illustrating the effect of this tax on the price that consumers pay, the price that producers receive, and the quantity of oil produced and consumed.
# (5	marks)
# P17
#
# d)	Calculate the change in CS, PS, EC, GR, and NB. Who gains and who loses from this policy? (5 marks)

# %%
solve(120 - 0.3*q- (24+0.3*q), q )
# Out:
# [160.0]

# %%
solve(120 - 0.3*q- (24+0.5*q), q )
# Out:
# [120.0]

# %%
(120 - 0.3*q).subs({q: 160})
# Out:
# 72.0000000000000

# %%
(120 - 0.3*q).subs({q: 120})
# Out:
# 84.0000000000000

# %%
pq3 = plot(120 - 0.3*q, 24+0.3*q, 24+0.5*q ,(q,0, 250), 
           line_color = ("blue") , xlim = (0, 250)  , ylim =(-10,130), 
           title = "Externality, MB ,MPC, MSC" ,legend = True, show = False )
pq3[1].line_color = 'red'
pq3[2].line_color = 'green'
pq3.show()

# %%
pq31 = plot_implicit(q - 160,  x_var=(q, 0, 250),  y_var =(y, 0, 120) ,line_color = "green", show = False)

pq32 = plot_implicit(q - 120,  x_var=(q, 0, 250),  y_var =(y, 0, 120) ,line_color = "green", show = False)


pq33 = plot_implicit(y - 72, y_var =(y, 0, 120) , x_var=(q, 0, 250),  line_color = "red", show = False)

pq34 = plot_implicit(y - 84, y_var =(y, 0, 120) , x_var=(q, 0, 250),  line_color = "red", show = False)

# %%
pq3.extend(pq31)
pq3.extend(pq32)
pq3.extend(pq33)
pq3.extend(pq34)
pq3.show()

# %% [markdown]
# ## Question 4 (10 marks)
#
# Suppose that the biological growth function for lobsters is given by G S =4S−0.1S!, where S is the size of the population and G is the amount of growth. S is in thousands of tonnes and G is in tonnes.
#
#     a)	Calculate the stock size that supports the maximum sustainable yield, SMSY. If the population is to be sustained at this size, how many tonnes of lobsters can be harvested perpetually? (3 marks)
# Let the harvest function be H(E,S) = eES, where e is the catchability coefficient and E is the harvesting effort. e is in tonnes caught per trap per thousand tonnes of stock and E is in number of lobster traps. Suppose that e = 0.01.
#
#     b)	How many traps need to be set to catch the MSY? Call this EMSY. (1 mark)
#
#     c)	Derive sustainable yield, or steady state harvest, as a function of effort, H(E).  (3 marks)
# Suppose the price of lobsters, P, is $1000/tonne, TB = PH(E), and TC = 200E.
#
#     d)	Derive the static efficient sustainable yield and the associated effort level.  (3 marks) Bonus:
#
#     e)	Illustrate your answers to (d) on a clearly labeled diagram. Show why EMSY is an inefficient level of effort. (4 marks)
#
#     f)	Show that the stock size that supports the static efficient sustainable yield is larger than SMSY. (1 mark)

# %%
from sympy import symbols
from sympy.plotting import plot
s = symbols('s')
pq4 = plot(4*s - 0.1* s**2, (s,0, 45), ylim =(-10,65), title = "Growth and Stock and Harvest" , legend = True)

# %%
g=4*s - 0.1* s**2
g
# Out:
#        2
# - 0.1⋅s  + 4⋅s

# %%
diff(4*s - 0.1* s**2, s)
# Out:
# -0.2⋅s + 4

# %%
solve(diff(4*s - 0.1* s**2, s), s)
# Out:
# [20.0]

# %%
(4*s - 0.1* s**2).subs({s:20})
# Out:
# 40.0000000000000

# %%
pq41 = plot_implicit(y - 40, y_var =(y, 0, 50) , x_var=(s, 0, 45),  line_color = "green", show = False)

pq42 = plot_implicit(s - 20,  x_var=(s, 0, 45), y_var =(y, 0, 50) , line_color = "green", show = False)

pq4.extend(pq41)
pq4.extend(pq42)

pq4.show()

# %%
e, Eff = symbols('e Eff')

# %%
h=0.01*Eff*s
h
# Out:
# 0.01⋅Eff⋅s

# %% [markdown]
# ####  G(S)= H(E,S)

# %%
sstar = solve(4*s - 0.1* s**2 - 0.01*Eff*s, s )[1]

# %%
sstar
# Out:
# -0.1⋅Eff + 40.0

# %%
h
# Out:
# 0.01⋅Eff⋅s

# %%
hstar=(0.01*Eff*s).subs({s:40-0.1*Eff})
hstar
# Out:
# 0.01⋅Eff⋅(-0.1⋅Eff + 40)

# %%
pq4he = plot( hstar, (Eff,0, 450), ylim = (-5, 45), title = "Harvest and Effort" , legend = True)

# %% [markdown]
# #### **NB is maximized when MB = MC.**

# %%
TC = 200*Eff
TC
# Out:
# 200⋅Eff

# %%
TB = 1000*hstar
TB
# Out:
# 10.0⋅Eff⋅(-0.1⋅Eff + 40)

# %%
pq4tb = plot(TB,  (Eff, 0, 450), ylim =(0, 45000) ,show = False, title = "Total Benefit and Total Cost", legend = True)
pq4tc = plot(TC,  (Eff, 0, 450),  line_color = "pink", show = False)
pq4mbmc = plot(TC+10000,  (Eff, 0, 450),  line_color = "green", show = False)
pq4estar = plot_implicit(Eff - 100,  x_var=(Eff, 0, 450), y_var =(y, 0, 45000) , line_color = "green", show = False)
pq4tb.extend(pq4tc)
pq4tb.extend(pq4mbmc)
pq4tb.extend(pq4estar)
pq4tb.show()

# %%
Effstar =solve(diff(TB, Eff)-diff(TC, Eff), Eff)
Effstar
# Out:
# [100.0]

# %%
hstar.subs({Eff:100})
# Out:
# 30.0000000000000

# %%
sstar.subs({Eff:100})
# Out:
# 30.0000000000000

# %%
h.subs({Eff:100})
# Out:
# 1.0⋅s

# %%
pq4d = plot_implicit(y - 30, y_var =(y, 0, 50) , x_var=(s, 0, 45),  line_color = "green", show = False)

pq4e = plot_implicit(s - 30,  x_var=(s, 0, 45), y_var =(y, 0, 50) , line_color = "green", show = False)

pq4f = plot(h.subs({Eff:100}),  (s, 0, 45),  line_color = "red", show = False)

pq4.extend(pq4d)
pq4.extend(pq4e)
pq4.extend(pq4f)
pq4.show()

# %%
from sympy import sympify, S, evalf, N

# %%
S('1/7')
# Out:
# 1/7

# %%
Rational(1,7)
# Out:
# 1/7

# %%
S('1')/7 #since a SymPy object divided by an int is a SymPy object
# Out:
# 1/7

# %% [markdown]
# When solving math problems, it’s best to work with SymPy objects,
# and wait to compute the numeric answer in the end. To obtain a
# numeric approximation of a SymPy object as a float, call its .evalf()
# method:
#
#
#
# The method .n() is equivalent to .evalf(). The global SymPy
# function N() can also be used to to compute numerical values. You can
# easily change the number of digits of precision of the approximation.
# Enter pi.n(400) to obtain an approximation of  to 400 decimals.

# %%
pi.evalf()
# Out:
# 3.14159265358979

# %% [markdown]
# ## Symbols

# %%
from sympy import Symbol, symbols

# %%
p = Symbol('p') # the same as p = symbols('p')

# %%
p + 2
# Out:
# p + 2

# %%
a0, a1, a2, a3 = symbols('a0:4')

# %% [markdown]
# You can use any name you want for a variable, but it’s best if you
# avoid the letters Q,C,O,S,I,N and E because they have special uses
# in SymPy:
#
# I is the unit imaginary number i
# p
# −1,
#
# E is the base of
# the natural logarithm,
#
# S() is the sympify function,
#
# N() is used to
# obtain numeric approximations, and
#
# O is used for big-O notation.
#
#
# The underscore symbol _ is a special variable that contains the result
# of the last printed value. The variable _ is analogous to the ans button
# on certain calculators, and is useful in multi-step calculations:

# %% [markdown]
# ## Expressions

# %%
from sympy import simplify, factor, expand, collect

# %%
expr = 2*x + 3*x - sin(x) - 3*x + 42
simplify(expr)
# Out:
# 2*x - sin(x) + 42

# %%
factor( x**2-2*x-8 )

expand( (x-4)*(x+2) )

collect(x**2 + x*b + a*x + a*b, x)
# Out:
# a*b + x**2 + x*(a + b)

# %% [markdown]
# To substitute a given value into an expression, call the .subs()
# method, passing in a python dictionary object { key:val, ... }
# with the symbol–value substitutions you want to make:

# %%
expr = sin(x) + cos(y)
expr
# Out:
# sin(x) + cos(y)

# %%
#sin(x) + cos(y)
expr.subs({x:1, y:2})
#sin(1) + cos(2)
# Out:
# cos(2) + sin(1)

# %%
expr.subs({x:1, y:2}).n()
# Out:
# 0.425324148260754

# %% [markdown]
# ## Solving equations

# %%
from sympy import solve

# %% [markdown]
# The function solve takes two arguments. Use solve(expr,var) to
# solve the equation expr==0 for the variable var. You can rewrite any
# equation in the form expr==0 by moving all the terms to one side
# of the equation; the solutions to A(x) = B(x) are the same as the
# solutions to A(x) − B(x) = 0.

# %%
solve( x**2 + 2*x - 8, x)
# Out:
# [-4, 2]

# %%
solve( a*x**2 + b*x + c, x)
# Out:
# [(-b + sqrt(-4*a*c + b**2))/(2*a), -(b + sqrt(-4*a*c + b**2))/(2*a)]

# %%
gen_sol = solve( a*x**2 + b*x + c, x)


[gen_sol[0].subs({'a':1,'b':2,'c':-8}),
gen_sol[1].subs({'a':1,'b':2,'c':-8}) ]
# Out:
# [2, -4]

# %%
[gen_sol[0].subs({a:1,b:2,c:-8}),
gen_sol[1].subs({a:1,b:2,c:-8}) ]
# Out:
# [2, -4]

# %% [markdown]
# To solve a system of equations, you can feed solve with the list of
# equations as the first argument, and specify the list of unknowns you
# want to solve for as the second argument. For example, to solve for x
# and y in the system of equations x + y = 3 and 3x − 2y = 0, us

# %%
solve([x + y - 3, 3*x - 2*y], [x, y])
# Out:
# {y: 9/5, x: 6/5}

# %%
h, k = symbols('h k')
solve( (x-h)**2 + k - (x**2-4*x+7), [h,k] )
# Out:
# [(2, 3)]

# %%
((x-2)**2+3).expand()
# Out:
# x**2 - 4*x + 7

# %% [markdown]
# ## Rational functions

# %%
from sympy import together, apart

# %%
a/b + c/d
# Out:
# a/b + c/d

# %%
together(a/b + c/d)
# Out:
# (a*d + b*c)/(b*d)

# %% [markdown]
# By default, SymPy assumes the inputs to functions like exp and log are
# complex numbers, so it will not expand certain logarithmic expressions.
# However, indicating to SymPy that the inputs are positive real numbers
# will make the expansions work:

# %%
a, b = symbols('a b', positive=True)
log(a*b).expand()
# Out:
# log(a) + log(b)

# %% [markdown]
# ## Polynomials
# Let’s define a polynomial P with roots at x = 1, x = 2, and x = 3:

# %%
P = (x-1)*(x-2)*(x-3)
P
# Out:
# (x - 3)*(x - 2)*(x - 1)

# %%
P.expand()
# Out:
# x**3 - 6*x**2 + 11*x - 6

# %%
P.factor()
# Out:
# (x - 3)*(x - 2)*(x - 1)

# %%
P.simplify()
# Out:
# (x - 3)*(x - 2)*(x - 1)

# %%
roots = solve(P,x)
roots
# Out:
# [1, 2, 3]

# %% [markdown]
# ## Equality checking
# In the last example, we used the simplify function to check whether
# two expressions were equal. This way of checking equality works
# because P = Q if and only if P − Q = 0. This is the best way to
# check if two expressions are equal in SymPy because it attempts all
# possible simplifications when comparing the expressions. Below is
# a list of other ways to check whether two quantities are equal with
# example cases where they fail:

# %%
p = (x-5)*(x+5)
q = x**2 - 25
p - q == 0
# Out:
# False

# %%
simplify(p - q) == 0
# Out:
# True

# %%
sin(x)**2 + cos(x)**2 == 1 # fail
# Out:
# False

# %%
simplify( sin(x)**2 + cos(x)**2 - 1 ) == 0
# Out:
# True

# %% [markdown]
# ## Trigonometry
# from sympy import sin, cos, tan, trigsimp, expand_trig
# The trigonometric functions sin and cos take inputs in radians:

# %%
sin(pi/6)
# Out:
# 1/2

# %%
cos(pi/6)
# Out:
# sqrt(3)/2

# %% [markdown]
# ## Hyperbolic trigonometric functions
# The hyperbolic sine and cosine in SymPy are denoted sinh and cosh
# respectively and SymPy is smart enough to recognize them when
# simplifying expressions:

# %% [markdown]
# # III. Calculus
# Calculus is the study of the properties of functions. The operations of
# calculus are used to describe the limit behaviour of functions, calculate
# their rates of change, and calculate the areas under their graphs. In
# this section we’ll learn about the SymPy functions for calculating
# limits, derivatives, integrals, and summations.
#
#
# ## Infinity

# %%
from sympy import oo

# %% [markdown]
# The infinity symbol is denoted oo (two lowercase os) in SymPy. Infinity
# is not a number but a process: the process of counting forever. Thus,
# 1 + 1 = 1, 1 is greater than any finite number, and 1/1 is an
# infinitely small number. Sympy knows how to correctly treat infinity
# in expressions:

# %% [markdown]
# ## Limits
#
# We use limits to describe, with mathematical precision, infinitely large
# quantities, infinitely small quantities, and procedures with infinitely
# many steps.
# The number e is defined as the limit e

# %%
from sympy import limit

# %%
limit( (1+1/n)**n, n, oo)
# Out:
# E

# %%
limit( 1/x, x, 0, dir="+")
# Out:
# oo

# %%
limit( 1/x, x, 0, dir="-")
# Out:
# -oo

# %% [markdown]
# ## Derivatives
# The derivative function, denoted f0(x), d
# dx f(x), df
# dx , or dy
# dx , describes
# the rate of change of the function f(x). The SymPy function diff
# computes the derivative of any expression:

# %%
diff(x**3, x)
# Out:
# 3*x**2

# %%
diff( x**2*sin(x), x )
# Out:
# x**2*cos(x) + 2*x*sin(x)

# %%
diff( x**2/sin(x), x )
# Out:
# -x**2*cos(x)/sin(x)**2 + 2*x/sin(x)

# %% [markdown]
# The second derivative of a function f is diff(f,x,2):

# %%
diff(x**3, x, 2)
# Out:
# 6*x

# %% [markdown]
# A differential equation is an equation that relates some unknown
# function f(x) to its derivative. An example of a differential equation
# is f0(x) = f(x). What is the function f(x) which is equal to its
# derivative? You can either try to guess what f(x) is or use the dsolve
# function:

# %%
x = symbols('x')
f = symbols('f', cls=Function) # can now use f(x)
dsolve( f(x) - diff(f(x),x), f(x) )
# Out:
# Eq(f(x), C1*exp(x))

# %% [markdown]
# ## Tangent lines
# The tangent line to the function f(x) at x = x0 is the line that passes
# through the point (x0, f(x0)) and has the same slope as the function
# at that point. The tangent line to the function f(x) at the point
# x = x0 is described by the equation
#
#
# T1(x) = f(x0) + f'(x0)(x − x0).
#
#
#
# What is the equation of the tangent line to f(x) = 1
# 2x2 at x0 = 1?

# %%
f = S('1/2')*x**2
f
# Out:
# x**2/2

# %%
df = diff(f, x)
df
# Out:
# x

# %%
T_1 = f.subs({x:1}) + df.subs({x:1})*(x - 1)
T_1  # y = x - 1/2
# Out:
# x - 1/2

# %% [markdown]
# The tangent line T1(x) has the same value and slope as the function f(x) at x = 1:

# %%
T_1.subs({x:1}) == f.subs({x:1})
# Out:
# True

# %%
diff(T_1, x).subs({x:1}) == diff(f, x).subs({x:1})
# Out:
# True

# %% [markdown]
# ## Optimization
# Optimization is about choosing an input for a function f(x) that
# results in the best value for f(x). The best value usually means the
# maximum value (if the function represents something desirable like
# profits) or the minimum value (if the function represents something
# undesirable like costs).
#
# The derivative f0(x) encodes the information about the slope of f(x).
# Positive slope f0(x) > 0 means f(x) is increasing, negative slope
# f0(x) < 0 means f(x) is decreasing, and zero slope f0(x) = 0 means
# the graph of the function is horizontal.
#
# The critical points of a function
# f(x) are the solutions to the equation f0(x) = 0. Each critical point
# is a candidate to be either a maximum or a minimum of the function.
# The second derivative f00(x) encodes the information about the
# curvature of f(x).
#
#
# Positive curvature means the function looks like x2,
# negative curvature means the function looks like −x2.
#
#
# Let’s find the critical points of the function f(x) = x3 − 2x2 + x and
# use the information from its second derivative to find the maximum
# of the function on the interval x 2 [0, 1].

# %%
x = Symbol('x')
f = x**3-2*x**2+x
diff(f, x)
# Out:
# 3*x**2 - 4*x + 1

# %%
sols = solve( diff(f,x), x)
sols
# Out:
# [1/3, 1]

# %%
diff(diff(f,x), x).subs( {x:sols[0]} )
# Out:
# -2

# %%
diff(diff(f,x), x).subs( {x:sols[1]} )
# Out:
# 2

# %% [markdown]
# ## Integrals
#
#
# The integral of f(x) corresponds to the computation of the area under
# the graph of f(x). The area under f(x) between the points x = a
# and x = b is denoted as follows:
#
# A(a, b) =
# Z b
# a
# f(x) dx.
#
# The integral function F corresponds to the area calculation as a
# function of the upper limit of integration:
#
# F(c)
# Z c
# 0
# f(x) dx .

# %% [markdown]
# In SymPy we use integrate(f, x) to obtain the integral function
# F(x) of any function f(x): F(x) =
# R x
# 0 f(u) du.

# %%
integrate(x**3, x)
# Out:
# x**4/4

# %%
integrate(sin(x), x)
# Out:
# -cos(x)

# %%
integrate(ln(x), x)
# Out:
# x*log(x) - x

# %% [markdown]
# This is known as an indefinite integral since the limits of integration
# are not defined.
# In contrast, a definite integral computes the area under f(x) between
# x = a and x = b. Use integrate(f, (x,a,b)) to compute the
# definite integrals of the form A(a, b) =
# R b
# a
# f(x) dx:

# %%
>>> integrate(x**3, (x,0,1))
# Out:
# 1/4

# %%
F = integrate(x**3, x)
>>> F.subs({x:1}) - F.subs({x:0})
# Out:
# 1/4

# %% [markdown]
# ## Plotting

# %%
# %matplotlib inline

# %%
>>> from sympy import symbols
>>> from sympy.plotting import plot
>>> x = symbols('x')
>>> p1 = plot(x*x)
>>> p2 = plot(x)
>>> p1.append(p2[0])
>>> p1

# %%
>>> from sympy import symbols
>>> from sympy.plotting import plot
>>> x = symbols('x')
>>> p1 = plot(x*x)
>>> p2 = plot(x)
>>> p1.append(p2[0])
>>> p1

# %%
plot(x**2, (x, -5, 5))

# %%
plot(x, x**2, x**3, (x, -5, 5))

# %%
 plot((x**2, (x, -6, 6)), (x, (x, -5, 5)))

# %%
>>> from sympy import symbols, cos, sin
>>> from sympy.plotting import plot_parametric
>>> u = symbols('u')

# %%
plot_parametric((cos(u), sin(u), (u, -5, 5)),\
     (cos(u), u, (u, -5, 5)))

# %%
>>> from sympy import symbols
>>> from sympy.plotting import plot3d
>>> x, y = symbols('x y')

# %%
plot3d(x*y, (x, -5, 5), (y, -5, 5))

# %%
plot3d(x*y, -x*y, (x, -5, 5), (y, -5, 5))

# %%
plot3d((x**2 + y**2, (x, -5, 5), (y, -5, 5)),
...     (x*y, (x, -3, 3), (y, -3, 3)))

# %%
>>> from sympy import plot_implicit, cos, sin, symbols, Eq, And
>>> x, y = symbols('x y')

# %%
>>> p1 = plot_implicit(Eq(x**2 + y**2, 5))

# %%
>>> p2 = plot_implicit(Eq(x**2 + y**2, 3),
...         (x, -3, 3), (y, -3, 3))

# %%
>>> p3 = plot_implicit(Eq(x**2 + y**2, 5),
...         (x, -4, 4), (y, -4, 4), depth = 2)

# %%
>>> p6 = plot_implicit(y > x**2)

# %%
>>> p7 = plot_implicit(And(y > x, y > -x))

# %%
>>> p8 = plot_implicit(y - 1, x_var=x)
>>> p=plot(x)
>>> p.extend(iplot(x-3))
>>> p.show()

# %%
>>> p8 = plot_implicit(y - 10, y_var=(y, 0, 15) ,x_var=(x, 0, 15))

# %%
>>> p9 = plot_implicit(y - 1, x_var=(x, 0,12),y_var=(y, 0, 15) )
